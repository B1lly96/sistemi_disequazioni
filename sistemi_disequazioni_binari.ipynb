# %%
quota_1 = 1.5
quota_2 = 3.5

puntata_1 = range( 1,1000 )
puntata_2 = range( 1,1000 )

over = 0.00

portafoglio = 200

print( "p1 | p2 | win_1 | win_2")
print("_ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _")
for v in puntata_1 :
    for val in puntata_2 :
        diff_eff_1 = quota_1*v-v-val
        diff_eff_2 = quota_2*val-v-val
        if v+val<=portafoglio :
            if ( diff_eff_1>over ) & ( diff_eff_2>over ) :
                print( v,"|", val,"|", diff_eff_1,"|", diff_eff_2 )
# Out:
# p1 | p2 | win_1 | win_2
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# 7 | 3 | 0.5 | 0.5
# 9 | 4 | 0.5 | 1.0
# 11 | 5 | 0.5 | 1.5
# 12 | 5 | 1.0 | 0.5
# 13 | 6 | 0.5 | 2.0
# 14 | 6 | 1.0 | 1.0
# 15 | 7 | 0.5 | 2.5
# 16 | 7 | 1.0 | 1.5
# 17 | 7 | 1.5 | 0.5
# 17 | 8 | 0.5 | 3.0
# 18 | 8 | 1.0 | 2.0
# 19 | 8 | 1.5 | 1.0
# 19 | 9 | 0.5 | 3.5
# 20 | 9 | 1.0 | 2.5
# 21 | 9 | 1.5 | 1.5
# 21 | 10 | 0.5 | 4.0
# 22 | 9 | 2.0 | 0.5
# 22 | 10 | 1.0 | 3.0
# 23 | 10 | 1.5 | 2.0
# 23 | 11 | 0.5 | 4.5
# 24 | 10 | 2.0 | 1.0
# 24 | 11 | 1.0 | 3.5
# 25 | 11 | 1.5 | 2.5
# 25 | 12 | 0.5 | 5.0
# 26 | 11 | 2.0 | 1.5
# 26 | 12 | 1.0 | 4.0
# 27 | 11 | 2.5 | 0.5
# 27 | 12 | 1.5 | 3.0
# 27 | 13 | 0.5 | 5.5
# 28 | 12 | 2.0 | 2.0
# 28 | 13 | 1.0 | 4.5
# 29 | 12 | 2.5 | 1.0
# 29 | 13 | 1.5 | 3.5
# 29 | 14 | 0.5 | 6.0
# 30 | 13 | 2.0 | 2.5
# 30 | 14 | 1.0 | 5.0
# 31 | 13 | 2.5 | 1.5
# 31 | 14 | 1.5 | 4.0
# 31 | 15 | 0.5 | 6.5
# 32 | 13 | 3.0 | 0.5
# 32 | 14 | 2.0 | 3.0
# 32 | 15 | 1.0 | 5.5
# 33 | 14 | 2.5 | 2.0
# 33 | 15 | 1.5 | 4.5
# 33 | 16 | 0.5 | 7.0
# 34 | 14 | 3.0 | 1.0
# 34 | 15 | 2.0 | 3.5
# 34 | 16 | 1.0 | 6.0
# 35 | 15 | 2.5 | 2.5
# 35 | 16 | 1.5 | 5.0
# 35 | 17 | 0.5 | 7.5
# 36 | 15 | 3.0 | 1.5
# 36 | 16 | 2.0 | 4.0
# 36 | 17 | 1.0 | 6.5
# 37 | 15 | 3.5 | 0.5
# 37 | 16 | 2.5 | 3.0
# 37 | 17 | 1.5 | 5.5
# 37 | 18 | 0.5 | 8.0
# 38 | 16 | 3.0 | 2.0
# 38 | 17 | 2.0 | 4.5
# 38 | 18 | 1.0 | 7.0
# 39 | 16 | 3.5 | 1.0
# 39 | 17 | 2.5 | 3.5
# 39 | 18 | 1.5 | 6.0
# 39 | 19 | 0.5 | 8.5
# 40 | 17 | 3.0 | 2.5
# 40 | 18 | 2.0 | 5.0
# 40 | 19 | 1.0 | 7.5
# 41 | 17 | 3.5 | 1.5
# 41 | 18 | 2.5 | 4.0
# 41 | 19 | 1.5 | 6.5
# 41 | 20 | 0.5 | 9.0
# 42 | 17 | 4.0 | 0.5
# 42 | 18 | 3.0 | 3.0
# 42 | 19 | 2.0 | 5.5
# 42 | 20 | 1.0 | 8.0
# 43 | 18 | 3.5 | 2.0
# 43 | 19 | 2.5 | 4.5
# 43 | 20 | 1.5 | 7.0
# 43 | 21 | 0.5 | 9.5
# 44 | 18 | 4.0 | 1.0
# 44 | 19 | 3.0 | 3.5
# 44 | 20 | 2.0 | 6.0
# 44 | 21 | 1.0 | 8.5
# 45 | 19 | 3.5 | 2.5
# 45 | 20 | 2.5 | 5.0
# 45 | 21 | 1.5 | 7.5
# 45 | 22 | 0.5 | 10.0
# 46 | 19 | 4.0 | 1.5
# 46 | 20 | 3.0 | 4.0
# 46 | 21 | 2.0 | 6.5
# 46 | 22 | 1.0 | 9.0
# 47 | 19 | 4.5 | 0.5
# 47 | 20 | 3.5 | 3.0
# 47 | 21 | 2.5 | 5.5
# 47 | 22 | 1.5 | 8.0
# 47 | 23 | 0.5 | 10.5
# 48 | 20 | 4.0 | 2.0
# 48 | 21 | 3.0 | 4.5
# 48 | 22 | 2.0 | 7.0
# 48 | 23 | 1.0 | 9.5
# 49 | 20 | 4.5 | 1.0
# 49 | 21 | 3.5 | 3.5
# 49 | 22 | 2.5 | 6.0
# 49 | 23 | 1.5 | 8.5
# 49 | 24 | 0.5 | 11.0
# 50 | 21 | 4.0 | 2.5
# 50 | 22 | 3.0 | 5.0
# 50 | 23 | 2.0 | 7.5
# 50 | 24 | 1.0 | 10.0
# 51 | 21 | 4.5 | 1.5
# 51 | 22 | 3.5 | 4.0
# 51 | 23 | 2.5 | 6.5
# 51 | 24 | 1.5 | 9.0
# 51 | 25 | 0.5 | 11.5
# 52 | 21 | 5.0 | 0.5
# 52 | 22 | 4.0 | 3.0
# 52 | 23 | 3.0 | 5.5
# 52 | 24 | 2.0 | 8.0
# 52 | 25 | 1.0 | 10.5
# 53 | 22 | 4.5 | 2.0
# 53 | 23 | 3.5 | 4.5
# 53 | 24 | 2.5 | 7.0
# 53 | 25 | 1.5 | 9.5
# 53 | 26 | 0.5 | 12.0
# 54 | 22 | 5.0 | 1.0
# 54 | 23 | 4.0 | 3.5
# 54 | 24 | 3.0 | 6.0
# 54 | 25 | 2.0 | 8.5
# 54 | 26 | 1.0 | 11.0
# 55 | 23 | 4.5 | 2.5
# 55 | 24 | 3.5 | 5.0
# 55 | 25 | 2.5 | 7.5
# 55 | 26 | 1.5 | 10.0
# 55 | 27 | 0.5 | 12.5
# 56 | 23 | 5.0 | 1.5
# 56 | 24 | 4.0 | 4.0
# 56 | 25 | 3.0 | 6.5
# 56 | 26 | 2.0 | 9.0
# 56 | 27 | 1.0 | 11.5
# 57 | 23 | 5.5 | 0.5
# 57 | 24 | 4.5 | 3.0
# 57 | 25 | 3.5 | 5.5
# 57 | 26 | 2.5 | 8.0
# 57 | 27 | 1.5 | 10.5
# 57 | 28 | 0.5 | 13.0
# 58 | 24 | 5.0 | 2.0
# 58 | 25 | 4.0 | 4.5
# 58 | 26 | 3.0 | 7.0
# 58 | 27 | 2.0 | 9.5
# 58 | 28 | 1.0 | 12.0
# 59 | 24 | 5.5 | 1.0
# 59 | 25 | 4.5 | 3.5
# 59 | 26 | 3.5 | 6.0
# 59 | 27 | 2.5 | 8.5
# 59 | 28 | 1.5 | 11.0
# 59 | 29 | 0.5 | 13.5
# 60 | 25 | 5.0 | 2.5
# 60 | 26 | 4.0 | 5.0
# 60 | 27 | 3.0 | 7.5
# 60 | 28 | 2.0 | 10.0
# 60 | 29 | 1.0 | 12.5
# 61 | 25 | 5.5 | 1.5
# 61 | 26 | 4.5 | 4.0
# 61 | 27 | 3.5 | 6.5
# 61 | 28 | 2.5 | 9.0
# 61 | 29 | 1.5 | 11.5
# 61 | 30 | 0.5 | 14.0
# 62 | 25 | 6.0 | 0.5
# 62 | 26 | 5.0 | 3.0
# 62 | 27 | 4.0 | 5.5
# 62 | 28 | 3.0 | 8.0
# 62 | 29 | 2.0 | 10.5
# 62 | 30 | 1.0 | 13.0
# 63 | 26 | 5.5 | 2.0
# 63 | 27 | 4.5 | 4.5
# 63 | 28 | 3.5 | 7.0
# 63 | 29 | 2.5 | 9.5
# 63 | 30 | 1.5 | 12.0
# 63 | 31 | 0.5 | 14.5
# 64 | 26 | 6.0 | 1.0
# 64 | 27 | 5.0 | 3.5
# 64 | 28 | 4.0 | 6.0
# 64 | 29 | 3.0 | 8.5
# 64 | 30 | 2.0 | 11.0
# 64 | 31 | 1.0 | 13.5
# 65 | 27 | 5.5 | 2.5
# 65 | 28 | 4.5 | 5.0
# 65 | 29 | 3.5 | 7.5
# 65 | 30 | 2.5 | 10.0
# 65 | 31 | 1.5 | 12.5
# 65 | 32 | 0.5 | 15.0
# 66 | 27 | 6.0 | 1.5
# 66 | 28 | 5.0 | 4.0
# 66 | 29 | 4.0 | 6.5
# 66 | 30 | 3.0 | 9.0
# 66 | 31 | 2.0 | 11.5
# 66 | 32 | 1.0 | 14.0
# 67 | 27 | 6.5 | 0.5
# 67 | 28 | 5.5 | 3.0
# 67 | 29 | 4.5 | 5.5
# 67 | 30 | 3.5 | 8.0
# 67 | 31 | 2.5 | 10.5
# 67 | 32 | 1.5 | 13.0
# 67 | 33 | 0.5 | 15.5
# 68 | 28 | 6.0 | 2.0
# 68 | 29 | 5.0 | 4.5
# 68 | 30 | 4.0 | 7.0
# 68 | 31 | 3.0 | 9.5
# 68 | 32 | 2.0 | 12.0
# 68 | 33 | 1.0 | 14.5
# 69 | 28 | 6.5 | 1.0
# 69 | 29 | 5.5 | 3.5
# 69 | 30 | 4.5 | 6.0
# 69 | 31 | 3.5 | 8.5
# 69 | 32 | 2.5 | 11.0
# 69 | 33 | 1.5 | 13.5
# 69 | 34 | 0.5 | 16.0
# 70 | 29 | 6.0 | 2.5
# 70 | 30 | 5.0 | 5.0
# 70 | 31 | 4.0 | 7.5
# 70 | 32 | 3.0 | 10.0
# 70 | 33 | 2.0 | 12.5
# 70 | 34 | 1.0 | 15.0
# 71 | 29 | 6.5 | 1.5
# 71 | 30 | 5.5 | 4.0
# 71 | 31 | 4.5 | 6.5
# 71 | 32 | 3.5 | 9.0
# 71 | 33 | 2.5 | 11.5
# 71 | 34 | 1.5 | 14.0
# 71 | 35 | 0.5 | 16.5
# 72 | 29 | 7.0 | 0.5
# 72 | 30 | 6.0 | 3.0
# 72 | 31 | 5.0 | 5.5
# 72 | 32 | 4.0 | 8.0
# 72 | 33 | 3.0 | 10.5
# 72 | 34 | 2.0 | 13.0
# 72 | 35 | 1.0 | 15.5
# 73 | 30 | 6.5 | 2.0
# 73 | 31 | 5.5 | 4.5
# 73 | 32 | 4.5 | 7.0
# 73 | 33 | 3.5 | 9.5
# 73 | 34 | 2.5 | 12.0
# 73 | 35 | 1.5 | 14.5
# 73 | 36 | 0.5 | 17.0
# 74 | 30 | 7.0 | 1.0
# 74 | 31 | 6.0 | 3.5
# 74 | 32 | 5.0 | 6.0
# 74 | 33 | 4.0 | 8.5
# 74 | 34 | 3.0 | 11.0
# 74 | 35 | 2.0 | 13.5
# 74 | 36 | 1.0 | 16.0
# 75 | 31 | 6.5 | 2.5
# 75 | 32 | 5.5 | 5.0
# 75 | 33 | 4.5 | 7.5
# 75 | 34 | 3.5 | 10.0
# 75 | 35 | 2.5 | 12.5
# 75 | 36 | 1.5 | 15.0
# 75 | 37 | 0.5 | 17.5
# 76 | 31 | 7.0 | 1.5
# 76 | 32 | 6.0 | 4.0
# 76 | 33 | 5.0 | 6.5
# 76 | 34 | 4.0 | 9.0
# 76 | 35 | 3.0 | 11.5
# 76 | 36 | 2.0 | 14.0
# 76 | 37 | 1.0 | 16.5
# 77 | 31 | 7.5 | 0.5
# 77 | 32 | 6.5 | 3.0
# 77 | 33 | 5.5 | 5.5
# 77 | 34 | 4.5 | 8.0
# 77 | 35 | 3.5 | 10.5
# 77 | 36 | 2.5 | 13.0
# 77 | 37 | 1.5 | 15.5
# 77 | 38 | 0.5 | 18.0
# 78 | 32 | 7.0 | 2.0
# 78 | 33 | 6.0 | 4.5
# 78 | 34 | 5.0 | 7.0
# 78 | 35 | 4.0 | 9.5
# 78 | 36 | 3.0 | 12.0
# 78 | 37 | 2.0 | 14.5
# 78 | 38 | 1.0 | 17.0
# 79 | 32 | 7.5 | 1.0
# 79 | 33 | 6.5 | 3.5
# 79 | 34 | 5.5 | 6.0
# 79 | 35 | 4.5 | 8.5
# 79 | 36 | 3.5 | 11.0
# 79 | 37 | 2.5 | 13.5
# 79 | 38 | 1.5 | 16.0
# 79 | 39 | 0.5 | 18.5
# 80 | 33 | 7.0 | 2.5
# 80 | 34 | 6.0 | 5.0
# 80 | 35 | 5.0 | 7.5
# 80 | 36 | 4.0 | 10.0
# 80 | 37 | 3.0 | 12.5
# 80 | 38 | 2.0 | 15.0
# 80 | 39 | 1.0 | 17.5
# 81 | 33 | 7.5 | 1.5
# 81 | 34 | 6.5 | 4.0
# 81 | 35 | 5.5 | 6.5
# 81 | 36 | 4.5 | 9.0
# 81 | 37 | 3.5 | 11.5
# 81 | 38 | 2.5 | 14.0
# 81 | 39 | 1.5 | 16.5
# 81 | 40 | 0.5 | 19.0
# 82 | 33 | 8.0 | 0.5
# 82 | 34 | 7.0 | 3.0
# 82 | 35 | 6.0 | 5.5
# 82 | 36 | 5.0 | 8.0
# 82 | 37 | 4.0 | 10.5
# 82 | 38 | 3.0 | 13.0
# 82 | 39 | 2.0 | 15.5
# 82 | 40 | 1.0 | 18.0
# 83 | 34 | 7.5 | 2.0
# 83 | 35 | 6.5 | 4.5
# 83 | 36 | 5.5 | 7.0
# 83 | 37 | 4.5 | 9.5
# 83 | 38 | 3.5 | 12.0
# 83 | 39 | 2.5 | 14.5
# 83 | 40 | 1.5 | 17.0
# 83 | 41 | 0.5 | 19.5
# 84 | 34 | 8.0 | 1.0
# 84 | 35 | 7.0 | 3.5
# 84 | 36 | 6.0 | 6.0
# 84 | 37 | 5.0 | 8.5
# 84 | 38 | 4.0 | 11.0
# 84 | 39 | 3.0 | 13.5
# 84 | 40 | 2.0 | 16.0
# 84 | 41 | 1.0 | 18.5
# 85 | 35 | 7.5 | 2.5
# 85 | 36 | 6.5 | 5.0
# 85 | 37 | 5.5 | 7.5
# 85 | 38 | 4.5 | 10.0
# 85 | 39 | 3.5 | 12.5
# 85 | 40 | 2.5 | 15.0
# 85 | 41 | 1.5 | 17.5
# 85 | 42 | 0.5 | 20.0
# 86 | 35 | 8.0 | 1.5
# 86 | 36 | 7.0 | 4.0
# 86 | 37 | 6.0 | 6.5
# 86 | 38 | 5.0 | 9.0
# 86 | 39 | 4.0 | 11.5
# 86 | 40 | 3.0 | 14.0
# 86 | 41 | 2.0 | 16.5
# 86 | 42 | 1.0 | 19.0
# 87 | 35 | 8.5 | 0.5
# 87 | 36 | 7.5 | 3.0
# 87 | 37 | 6.5 | 5.5
# 87 | 38 | 5.5 | 8.0
# 87 | 39 | 4.5 | 10.5
# 87 | 40 | 3.5 | 13.0
# 87 | 41 | 2.5 | 15.5
# 87 | 42 | 1.5 | 18.0
# 87 | 43 | 0.5 | 20.5
# 88 | 36 | 8.0 | 2.0
# 88 | 37 | 7.0 | 4.5
# 88 | 38 | 6.0 | 7.0
# 88 | 39 | 5.0 | 9.5
# 88 | 40 | 4.0 | 12.0
# 88 | 41 | 3.0 | 14.5
# 88 | 42 | 2.0 | 17.0
# 88 | 43 | 1.0 | 19.5
# 89 | 36 | 8.5 | 1.0
# 89 | 37 | 7.5 | 3.5
# 89 | 38 | 6.5 | 6.0
# 89 | 39 | 5.5 | 8.5
# 89 | 40 | 4.5 | 11.0
# 89 | 41 | 3.5 | 13.5
# 89 | 42 | 2.5 | 16.0
# 89 | 43 | 1.5 | 18.5
# 89 | 44 | 0.5 | 21.0
# 90 | 37 | 8.0 | 2.5
# 90 | 38 | 7.0 | 5.0
# 90 | 39 | 6.0 | 7.5
# 90 | 40 | 5.0 | 10.0
# 90 | 41 | 4.0 | 12.5
# 90 | 42 | 3.0 | 15.0
# 90 | 43 | 2.0 | 17.5
# 90 | 44 | 1.0 | 20.0
# 91 | 37 | 8.5 | 1.5
# 91 | 38 | 7.5 | 4.0
# 91 | 39 | 6.5 | 6.5
# 91 | 40 | 5.5 | 9.0
# 91 | 41 | 4.5 | 11.5
# 91 | 42 | 3.5 | 14.0
# 91 | 43 | 2.5 | 16.5
# 91 | 44 | 1.5 | 19.0
# 91 | 45 | 0.5 | 21.5
# 92 | 37 | 9.0 | 0.5
# 92 | 38 | 8.0 | 3.0
# 92 | 39 | 7.0 | 5.5
# 92 | 40 | 6.0 | 8.0
# 92 | 41 | 5.0 | 10.5
# 92 | 42 | 4.0 | 13.0
# 92 | 43 | 3.0 | 15.5
# 92 | 44 | 2.0 | 18.0
# 92 | 45 | 1.0 | 20.5
# 93 | 38 | 8.5 | 2.0
# 93 | 39 | 7.5 | 4.5
# 93 | 40 | 6.5 | 7.0
# 93 | 41 | 5.5 | 9.5
# 93 | 42 | 4.5 | 12.0
# 93 | 43 | 3.5 | 14.5
# 93 | 44 | 2.5 | 17.0
# 93 | 45 | 1.5 | 19.5
# 93 | 46 | 0.5 | 22.0
# 94 | 38 | 9.0 | 1.0
# 94 | 39 | 8.0 | 3.5
# 94 | 40 | 7.0 | 6.0
# 94 | 41 | 6.0 | 8.5
# 94 | 42 | 5.0 | 11.0
# 94 | 43 | 4.0 | 13.5
# 94 | 44 | 3.0 | 16.0
# 94 | 45 | 2.0 | 18.5
# 94 | 46 | 1.0 | 21.0
# 95 | 39 | 8.5 | 2.5
# 95 | 40 | 7.5 | 5.0
# 95 | 41 | 6.5 | 7.5
# 95 | 42 | 5.5 | 10.0
# 95 | 43 | 4.5 | 12.5
# 95 | 44 | 3.5 | 15.0
# 95 | 45 | 2.5 | 17.5
# 95 | 46 | 1.5 | 20.0
# 95 | 47 | 0.5 | 22.5
# 96 | 39 | 9.0 | 1.5
# 96 | 40 | 8.0 | 4.0
# 96 | 41 | 7.0 | 6.5
# 96 | 42 | 6.0 | 9.0
# 96 | 43 | 5.0 | 11.5
# 96 | 44 | 4.0 | 14.0
# 96 | 45 | 3.0 | 16.5
# 96 | 46 | 2.0 | 19.0
# 96 | 47 | 1.0 | 21.5
# 97 | 39 | 9.5 | 0.5
# 97 | 40 | 8.5 | 3.0
# 97 | 41 | 7.5 | 5.5
# 97 | 42 | 6.5 | 8.0
# 97 | 43 | 5.5 | 10.5
# 97 | 44 | 4.5 | 13.0
# 97 | 45 | 3.5 | 15.5
# 97 | 46 | 2.5 | 18.0
# 97 | 47 | 1.5 | 20.5
# 97 | 48 | 0.5 | 23.0
# 98 | 40 | 9.0 | 2.0
# 98 | 41 | 8.0 | 4.5
# 98 | 42 | 7.0 | 7.0
# 98 | 43 | 6.0 | 9.5
# 98 | 44 | 5.0 | 12.0
# 98 | 45 | 4.0 | 14.5
# 98 | 46 | 3.0 | 17.0
# 98 | 47 | 2.0 | 19.5
# 98 | 48 | 1.0 | 22.0
# 99 | 40 | 9.5 | 1.0
# 99 | 41 | 8.5 | 3.5
# 99 | 42 | 7.5 | 6.0
# 99 | 43 | 6.5 | 8.5
# 99 | 44 | 5.5 | 11.0
# 99 | 45 | 4.5 | 13.5
# 99 | 46 | 3.5 | 16.0
# 99 | 47 | 2.5 | 18.5
# 99 | 48 | 1.5 | 21.0
# 99 | 49 | 0.5 | 23.5
# 100 | 41 | 9.0 | 2.5
# 100 | 42 | 8.0 | 5.0
# 100 | 43 | 7.0 | 7.5
# 100 | 44 | 6.0 | 10.0
# 100 | 45 | 5.0 | 12.5
# 100 | 46 | 4.0 | 15.0
# 100 | 47 | 3.0 | 17.5
# 100 | 48 | 2.0 | 20.0
# 100 | 49 | 1.0 | 22.5
# 101 | 41 | 9.5 | 1.5
# 101 | 42 | 8.5 | 4.0
# 101 | 43 | 7.5 | 6.5
# 101 | 44 | 6.5 | 9.0
# 101 | 45 | 5.5 | 11.5
# 101 | 46 | 4.5 | 14.0
# 101 | 47 | 3.5 | 16.5
# 101 | 48 | 2.5 | 19.0
# 101 | 49 | 1.5 | 21.5
# 101 | 50 | 0.5 | 24.0
# 102 | 41 | 10.0 | 0.5
# 102 | 42 | 9.0 | 3.0
# 102 | 43 | 8.0 | 5.5
# 102 | 44 | 7.0 | 8.0
# 102 | 45 | 6.0 | 10.5
# 102 | 46 | 5.0 | 13.0
# 102 | 47 | 4.0 | 15.5
# 102 | 48 | 3.0 | 18.0
# 102 | 49 | 2.0 | 20.5
# 102 | 50 | 1.0 | 23.0
# 103 | 42 | 9.5 | 2.0
# 103 | 43 | 8.5 | 4.5
# 103 | 44 | 7.5 | 7.0
# 103 | 45 | 6.5 | 9.5
# 103 | 46 | 5.5 | 12.0
# 103 | 47 | 4.5 | 14.5
# 103 | 48 | 3.5 | 17.0
# 103 | 49 | 2.5 | 19.5
# 103 | 50 | 1.5 | 22.0
# 103 | 51 | 0.5 | 24.5
# 104 | 42 | 10.0 | 1.0
# 104 | 43 | 9.0 | 3.5
# 104 | 44 | 8.0 | 6.0
# 104 | 45 | 7.0 | 8.5
# 104 | 46 | 6.0 | 11.0
# 104 | 47 | 5.0 | 13.5
# 104 | 48 | 4.0 | 16.0
# 104 | 49 | 3.0 | 18.5
# 104 | 50 | 2.0 | 21.0
# 104 | 51 | 1.0 | 23.5
# 105 | 43 | 9.5 | 2.5
# 105 | 44 | 8.5 | 5.0
# 105 | 45 | 7.5 | 7.5
# 105 | 46 | 6.5 | 10.0
# 105 | 47 | 5.5 | 12.5
# 105 | 48 | 4.5 | 15.0
# 105 | 49 | 3.5 | 17.5
# 105 | 50 | 2.5 | 20.0
# 105 | 51 | 1.5 | 22.5
# 105 | 52 | 0.5 | 25.0
# 106 | 43 | 10.0 | 1.5
# 106 | 44 | 9.0 | 4.0
# 106 | 45 | 8.0 | 6.5
# 106 | 46 | 7.0 | 9.0
# 106 | 47 | 6.0 | 11.5
# 106 | 48 | 5.0 | 14.0
# 106 | 49 | 4.0 | 16.5
# 106 | 50 | 3.0 | 19.0
# 106 | 51 | 2.0 | 21.5
# 106 | 52 | 1.0 | 24.0
# 107 | 43 | 10.5 | 0.5
# 107 | 44 | 9.5 | 3.0
# 107 | 45 | 8.5 | 5.5
# 107 | 46 | 7.5 | 8.0
# 107 | 47 | 6.5 | 10.5
# 107 | 48 | 5.5 | 13.0
# 107 | 49 | 4.5 | 15.5
# 107 | 50 | 3.5 | 18.0
# 107 | 51 | 2.5 | 20.5
# 107 | 52 | 1.5 | 23.0
# 107 | 53 | 0.5 | 25.5
# 108 | 44 | 10.0 | 2.0
# 108 | 45 | 9.0 | 4.5
# 108 | 46 | 8.0 | 7.0
# 108 | 47 | 7.0 | 9.5
# 108 | 48 | 6.0 | 12.0
# 108 | 49 | 5.0 | 14.5
# 108 | 50 | 4.0 | 17.0
# 108 | 51 | 3.0 | 19.5
# 108 | 52 | 2.0 | 22.0
# 108 | 53 | 1.0 | 24.5
# 109 | 44 | 10.5 | 1.0
# 109 | 45 | 9.5 | 3.5
# 109 | 46 | 8.5 | 6.0
# 109 | 47 | 7.5 | 8.5
# 109 | 48 | 6.5 | 11.0
# 109 | 49 | 5.5 | 13.5
# 109 | 50 | 4.5 | 16.0
# 109 | 51 | 3.5 | 18.5
# 109 | 52 | 2.5 | 21.0
# 109 | 53 | 1.5 | 23.5
# 109 | 54 | 0.5 | 26.0
# 110 | 45 | 10.0 | 2.5
# 110 | 46 | 9.0 | 5.0
# 110 | 47 | 8.0 | 7.5
# 110 | 48 | 7.0 | 10.0
# 110 | 49 | 6.0 | 12.5
# 110 | 50 | 5.0 | 15.0
# 110 | 51 | 4.0 | 17.5
# 110 | 52 | 3.0 | 20.0
# 110 | 53 | 2.0 | 22.5
# 110 | 54 | 1.0 | 25.0
# 111 | 45 | 10.5 | 1.5
# 111 | 46 | 9.5 | 4.0
# 111 | 47 | 8.5 | 6.5
# 111 | 48 | 7.5 | 9.0
# 111 | 49 | 6.5 | 11.5
# 111 | 50 | 5.5 | 14.0
# 111 | 51 | 4.5 | 16.5
# 111 | 52 | 3.5 | 19.0
# 111 | 53 | 2.5 | 21.5
# 111 | 54 | 1.5 | 24.0
# 111 | 55 | 0.5 | 26.5
# 112 | 45 | 11.0 | 0.5
# 112 | 46 | 10.0 | 3.0
# 112 | 47 | 9.0 | 5.5
# 112 | 48 | 8.0 | 8.0
# 112 | 49 | 7.0 | 10.5
# 112 | 50 | 6.0 | 13.0
# 112 | 51 | 5.0 | 15.5
# 112 | 52 | 4.0 | 18.0
# 112 | 53 | 3.0 | 20.5
# 112 | 54 | 2.0 | 23.0
# 112 | 55 | 1.0 | 25.5
# 113 | 46 | 10.5 | 2.0
# 113 | 47 | 9.5 | 4.5
# 113 | 48 | 8.5 | 7.0
# 113 | 49 | 7.5 | 9.5
# 113 | 50 | 6.5 | 12.0
# 113 | 51 | 5.5 | 14.5
# 113 | 52 | 4.5 | 17.0
# 113 | 53 | 3.5 | 19.5
# 113 | 54 | 2.5 | 22.0
# 113 | 55 | 1.5 | 24.5
# 113 | 56 | 0.5 | 27.0
# 114 | 46 | 11.0 | 1.0
# 114 | 47 | 10.0 | 3.5
# 114 | 48 | 9.0 | 6.0
# 114 | 49 | 8.0 | 8.5
# 114 | 50 | 7.0 | 11.0
# 114 | 51 | 6.0 | 13.5
# 114 | 52 | 5.0 | 16.0
# 114 | 53 | 4.0 | 18.5
# 114 | 54 | 3.0 | 21.0
# 114 | 55 | 2.0 | 23.5
# 114 | 56 | 1.0 | 26.0
# 115 | 47 | 10.5 | 2.5
# 115 | 48 | 9.5 | 5.0
# 115 | 49 | 8.5 | 7.5
# 115 | 50 | 7.5 | 10.0
# 115 | 51 | 6.5 | 12.5
# 115 | 52 | 5.5 | 15.0
# 115 | 53 | 4.5 | 17.5
# 115 | 54 | 3.5 | 20.0
# 115 | 55 | 2.5 | 22.5
# 115 | 56 | 1.5 | 25.0
# 115 | 57 | 0.5 | 27.5
# 116 | 47 | 11.0 | 1.5
# 116 | 48 | 10.0 | 4.0
# 116 | 49 | 9.0 | 6.5
# 116 | 50 | 8.0 | 9.0
# 116 | 51 | 7.0 | 11.5
# 116 | 52 | 6.0 | 14.0
# 116 | 53 | 5.0 | 16.5
# 116 | 54 | 4.0 | 19.0
# 116 | 55 | 3.0 | 21.5
# 116 | 56 | 2.0 | 24.0
# 116 | 57 | 1.0 | 26.5
# 117 | 47 | 11.5 | 0.5
# 117 | 48 | 10.5 | 3.0
# 117 | 49 | 9.5 | 5.5
# 117 | 50 | 8.5 | 8.0
# 117 | 51 | 7.5 | 10.5
# 117 | 52 | 6.5 | 13.0
# 117 | 53 | 5.5 | 15.5
# 117 | 54 | 4.5 | 18.0
# 117 | 55 | 3.5 | 20.5
# 117 | 56 | 2.5 | 23.0
# 117 | 57 | 1.5 | 25.5
# 117 | 58 | 0.5 | 28.0
# 118 | 48 | 11.0 | 2.0
# 118 | 49 | 10.0 | 4.5
# 118 | 50 | 9.0 | 7.0
# 118 | 51 | 8.0 | 9.5
# 118 | 52 | 7.0 | 12.0
# 118 | 53 | 6.0 | 14.5
# 118 | 54 | 5.0 | 17.0
# 118 | 55 | 4.0 | 19.5
# 118 | 56 | 3.0 | 22.0
# 118 | 57 | 2.0 | 24.5
# 118 | 58 | 1.0 | 27.0
# 119 | 48 | 11.5 | 1.0
# 119 | 49 | 10.5 | 3.5
# 119 | 50 | 9.5 | 6.0
# 119 | 51 | 8.5 | 8.5
# 119 | 52 | 7.5 | 11.0
# 119 | 53 | 6.5 | 13.5
# 119 | 54 | 5.5 | 16.0
# 119 | 55 | 4.5 | 18.5
# 119 | 56 | 3.5 | 21.0
# 119 | 57 | 2.5 | 23.5
# 119 | 58 | 1.5 | 26.0
# 119 | 59 | 0.5 | 28.5
# 120 | 49 | 11.0 | 2.5
# 120 | 50 | 10.0 | 5.0
# 120 | 51 | 9.0 | 7.5
# 120 | 52 | 8.0 | 10.0
# 120 | 53 | 7.0 | 12.5
# 120 | 54 | 6.0 | 15.0
# 120 | 55 | 5.0 | 17.5
# 120 | 56 | 4.0 | 20.0
# 120 | 57 | 3.0 | 22.5
# 120 | 58 | 2.0 | 25.0
# 120 | 59 | 1.0 | 27.5
# 121 | 49 | 11.5 | 1.5
# 121 | 50 | 10.5 | 4.0
# 121 | 51 | 9.5 | 6.5
# 121 | 52 | 8.5 | 9.0
# 121 | 53 | 7.5 | 11.5
# 121 | 54 | 6.5 | 14.0
# 121 | 55 | 5.5 | 16.5
# 121 | 56 | 4.5 | 19.0
# 121 | 57 | 3.5 | 21.5
# 121 | 58 | 2.5 | 24.0
# 121 | 59 | 1.5 | 26.5
# 121 | 60 | 0.5 | 29.0
# 122 | 49 | 12.0 | 0.5
# 122 | 50 | 11.0 | 3.0
# 122 | 51 | 10.0 | 5.5
# 122 | 52 | 9.0 | 8.0
# 122 | 53 | 8.0 | 10.5
# 122 | 54 | 7.0 | 13.0
# 122 | 55 | 6.0 | 15.5
# 122 | 56 | 5.0 | 18.0
# 122 | 57 | 4.0 | 20.5
# 122 | 58 | 3.0 | 23.0
# 122 | 59 | 2.0 | 25.5
# 122 | 60 | 1.0 | 28.0
# 123 | 50 | 11.5 | 2.0
# 123 | 51 | 10.5 | 4.5
# 123 | 52 | 9.5 | 7.0
# 123 | 53 | 8.5 | 9.5
# 123 | 54 | 7.5 | 12.0
# 123 | 55 | 6.5 | 14.5
# 123 | 56 | 5.5 | 17.0
# 123 | 57 | 4.5 | 19.5
# 123 | 58 | 3.5 | 22.0
# 123 | 59 | 2.5 | 24.5
# 123 | 60 | 1.5 | 27.0
# 123 | 61 | 0.5 | 29.5
# 124 | 50 | 12.0 | 1.0
# 124 | 51 | 11.0 | 3.5
# 124 | 52 | 10.0 | 6.0
# 124 | 53 | 9.0 | 8.5
# 124 | 54 | 8.0 | 11.0
# 124 | 55 | 7.0 | 13.5
# 124 | 56 | 6.0 | 16.0
# 124 | 57 | 5.0 | 18.5
# 124 | 58 | 4.0 | 21.0
# 124 | 59 | 3.0 | 23.5
# 124 | 60 | 2.0 | 26.0
# 124 | 61 | 1.0 | 28.5
# 125 | 51 | 11.5 | 2.5
# 125 | 52 | 10.5 | 5.0
# 125 | 53 | 9.5 | 7.5
# 125 | 54 | 8.5 | 10.0
# 125 | 55 | 7.5 | 12.5
# 125 | 56 | 6.5 | 15.0
# 125 | 57 | 5.5 | 17.5
# 125 | 58 | 4.5 | 20.0
# 125 | 59 | 3.5 | 22.5
# 125 | 60 | 2.5 | 25.0
# 125 | 61 | 1.5 | 27.5
# 125 | 62 | 0.5 | 30.0
# 126 | 51 | 12.0 | 1.5
# 126 | 52 | 11.0 | 4.0
# 126 | 53 | 10.0 | 6.5
# 126 | 54 | 9.0 | 9.0
# 126 | 55 | 8.0 | 11.5
# 126 | 56 | 7.0 | 14.0
# 126 | 57 | 6.0 | 16.5
# 126 | 58 | 5.0 | 19.0
# 126 | 59 | 4.0 | 21.5
# 126 | 60 | 3.0 | 24.0
# 126 | 61 | 2.0 | 26.5
# 126 | 62 | 1.0 | 29.0
# 127 | 51 | 12.5 | 0.5
# 127 | 52 | 11.5 | 3.0
# 127 | 53 | 10.5 | 5.5
# 127 | 54 | 9.5 | 8.0
# 127 | 55 | 8.5 | 10.5
# 127 | 56 | 7.5 | 13.0
# 127 | 57 | 6.5 | 15.5
# 127 | 58 | 5.5 | 18.0
# 127 | 59 | 4.5 | 20.5
# 127 | 60 | 3.5 | 23.0
# 127 | 61 | 2.5 | 25.5
# 127 | 62 | 1.5 | 28.0
# 127 | 63 | 0.5 | 30.5
# 128 | 52 | 12.0 | 2.0
# 128 | 53 | 11.0 | 4.5
# 128 | 54 | 10.0 | 7.0
# 128 | 55 | 9.0 | 9.5
# 128 | 56 | 8.0 | 12.0
# 128 | 57 | 7.0 | 14.5
# 128 | 58 | 6.0 | 17.0
# 128 | 59 | 5.0 | 19.5
# 128 | 60 | 4.0 | 22.0
# 128 | 61 | 3.0 | 24.5
# 128 | 62 | 2.0 | 27.0
# 128 | 63 | 1.0 | 29.5
# 129 | 52 | 12.5 | 1.0
# 129 | 53 | 11.5 | 3.5
# 129 | 54 | 10.5 | 6.0
# 129 | 55 | 9.5 | 8.5
# 129 | 56 | 8.5 | 11.0
# 129 | 57 | 7.5 | 13.5
# 129 | 58 | 6.5 | 16.0
# 129 | 59 | 5.5 | 18.5
# 129 | 60 | 4.5 | 21.0
# 129 | 61 | 3.5 | 23.5
# 129 | 62 | 2.5 | 26.0
# 129 | 63 | 1.5 | 28.5
# 129 | 64 | 0.5 | 31.0
# 130 | 53 | 12.0 | 2.5
# 130 | 54 | 11.0 | 5.0
# 130 | 55 | 10.0 | 7.5
# 130 | 56 | 9.0 | 10.0
# 130 | 57 | 8.0 | 12.5
# 130 | 58 | 7.0 | 15.0
# 130 | 59 | 6.0 | 17.5
# 130 | 60 | 5.0 | 20.0
# 130 | 61 | 4.0 | 22.5
# 130 | 62 | 3.0 | 25.0
# 130 | 63 | 2.0 | 27.5
# 130 | 64 | 1.0 | 30.0
# 131 | 53 | 12.5 | 1.5
# 131 | 54 | 11.5 | 4.0
# 131 | 55 | 10.5 | 6.5
# 131 | 56 | 9.5 | 9.0
# 131 | 57 | 8.5 | 11.5
# 131 | 58 | 7.5 | 14.0
# 131 | 59 | 6.5 | 16.5
# 131 | 60 | 5.5 | 19.0
# 131 | 61 | 4.5 | 21.5
# 131 | 62 | 3.5 | 24.0
# 131 | 63 | 2.5 | 26.5
# 131 | 64 | 1.5 | 29.0
# 131 | 65 | 0.5 | 31.5
# 132 | 53 | 13.0 | 0.5
# 132 | 54 | 12.0 | 3.0
# 132 | 55 | 11.0 | 5.5
# 132 | 56 | 10.0 | 8.0
# 132 | 57 | 9.0 | 10.5
# 132 | 58 | 8.0 | 13.0
# 132 | 59 | 7.0 | 15.5
# 132 | 60 | 6.0 | 18.0
# 132 | 61 | 5.0 | 20.5
# 132 | 62 | 4.0 | 23.0
# 132 | 63 | 3.0 | 25.5
# 132 | 64 | 2.0 | 28.0
# 132 | 65 | 1.0 | 30.5
# 133 | 54 | 12.5 | 2.0
# 133 | 55 | 11.5 | 4.5
# 133 | 56 | 10.5 | 7.0
# 133 | 57 | 9.5 | 9.5
# 133 | 58 | 8.5 | 12.0
# 133 | 59 | 7.5 | 14.5
# 133 | 60 | 6.5 | 17.0
# 133 | 61 | 5.5 | 19.5
# 133 | 62 | 4.5 | 22.0
# 133 | 63 | 3.5 | 24.5
# 133 | 64 | 2.5 | 27.0
# 133 | 65 | 1.5 | 29.5
# 133 | 66 | 0.5 | 32.0
# 134 | 54 | 13.0 | 1.0
# 134 | 55 | 12.0 | 3.5
# 134 | 56 | 11.0 | 6.0
# 134 | 57 | 10.0 | 8.5
# 134 | 58 | 9.0 | 11.0
# 134 | 59 | 8.0 | 13.5
# 134 | 60 | 7.0 | 16.0
# 134 | 61 | 6.0 | 18.5
# 134 | 62 | 5.0 | 21.0
# 134 | 63 | 4.0 | 23.5
# 134 | 64 | 3.0 | 26.0
# 134 | 65 | 2.0 | 28.5
# 134 | 66 | 1.0 | 31.0
# 135 | 55 | 12.5 | 2.5
# 135 | 56 | 11.5 | 5.0
# 135 | 57 | 10.5 | 7.5
# 135 | 58 | 9.5 | 10.0
# 135 | 59 | 8.5 | 12.5
# 135 | 60 | 7.5 | 15.0
# 135 | 61 | 6.5 | 17.5
# 135 | 62 | 5.5 | 20.0
# 135 | 63 | 4.5 | 22.5
# 135 | 64 | 3.5 | 25.0
# 135 | 65 | 2.5 | 27.5
# 136 | 55 | 13.0 | 1.5
# 136 | 56 | 12.0 | 4.0
# 136 | 57 | 11.0 | 6.5
# 136 | 58 | 10.0 | 9.0
# 136 | 59 | 9.0 | 11.5
# 136 | 60 | 8.0 | 14.0
# 136 | 61 | 7.0 | 16.5
# 136 | 62 | 6.0 | 19.0
# 136 | 63 | 5.0 | 21.5
# 136 | 64 | 4.0 | 24.0
# 137 | 55 | 13.5 | 0.5
# 137 | 56 | 12.5 | 3.0
# 137 | 57 | 11.5 | 5.5
# 137 | 58 | 10.5 | 8.0
# 137 | 59 | 9.5 | 10.5
# 137 | 60 | 8.5 | 13.0
# 137 | 61 | 7.5 | 15.5
# 137 | 62 | 6.5 | 18.0
# 137 | 63 | 5.5 | 20.5
# 138 | 56 | 13.0 | 2.0
# 138 | 57 | 12.0 | 4.5
# 138 | 58 | 11.0 | 7.0
# 138 | 59 | 10.0 | 9.5
# 138 | 60 | 9.0 | 12.0
# 138 | 61 | 8.0 | 14.5
# 138 | 62 | 7.0 | 17.0
# 139 | 56 | 13.5 | 1.0
# 139 | 57 | 12.5 | 3.5
# 139 | 58 | 11.5 | 6.0
# 139 | 59 | 10.5 | 8.5
# 139 | 60 | 9.5 | 11.0
# 139 | 61 | 8.5 | 13.5
# 140 | 57 | 13.0 | 2.5
# 140 | 58 | 12.0 | 5.0
# 140 | 59 | 11.0 | 7.5
# 140 | 60 | 10.0 | 10.0
# 141 | 57 | 13.5 | 1.5
# 141 | 58 | 12.5 | 4.0
# 141 | 59 | 11.5 | 6.5
# 142 | 57 | 14.0 | 0.5
# 142 | 58 | 13.0 | 3.0
